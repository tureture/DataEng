# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()
# Out:
# <AxesSubplot: >

# %%
print('tset123321')
# Out:
# tset123321

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2
